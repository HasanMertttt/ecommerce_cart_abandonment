# %% [markdown]
# # Data Cleaning
#
# This notebook focuses on transforming the raw dataset into a reliable analytical dataset by addressing missing values, standardizing formats, and creating additional fields for downstream analysis.

# %%
import pandas as pd

raw_df = pd.read_csv('ecommerce_cart_data_raw.csv')

median_cart_val = raw_df['cart_value'].median()
raw_df['cart_value'] = raw_df['cart_value'].fillna(median_cart_val)
raw_df['device_type'] = raw_df['device_type'].fillna('Unknown')
raw_df['session_start_time'] = pd.to_datetime(raw_df['session_start_time'])
raw_df['hour_of_day'] = raw_df['session_start_time'].dt.hour
raw_df['day_of_week'] = raw_df['session_start_time'].dt.day_name()

raw_df.to_csv('ecommerce_cart_data_cleaned.csv', index=False)
print('Cleaning complete. Cleaned dataset saved to ecommerce_cart_data_cleaned.csv')
raw_df.head()
# Out:
# e:\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# e:\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
# Cleaning complete. Cleaned dataset saved to ecommerce_cart_data_cleaned.csv
#      user_id  session_start_time device_type  cart_value checkout_status  \
# 0  USER_0563 2026-01-01 00:15:17     Desktop      154.53       Abandoned
# 1  USER_0598 2026-01-01 01:06:51      Mobile       42.24       Abandoned
# 2  USER_0400 2026-01-01 01:47:44      Mobile       38.67       Abandoned
# 3  USER_0534 2026-01-01 03:34:39     Unknown       24.78       Abandoned
# 4  USER_0476 2026-01-01 05:19:16      Tablet       90.41       Completed
#
# ...
